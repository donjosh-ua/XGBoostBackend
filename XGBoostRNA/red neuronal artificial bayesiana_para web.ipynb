# %% [markdown]
# # Implementación bayesiana (parámetros y softmax) para el caso de bases de datos normales e imagenes

# %% [markdown]
# # Aplicacion de la libreria RedNeuBay

# %%
import torchvision.datasets as dset
import torchvision
import torchvision.transforms as transformsb
from redneuronal_bay.RedNeuBay import RedNeuBay
from redneuronal_bay.Layers.layers import *
from redneuronal_bay.preprocesamiento import *
from redneuronal_bay.metricas_eva import * 
from redneuronal_bay.funcion_activacion import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import torchvision.datasets as dset
#       2 import torchvision
#       3 import torchvision.transforms as transformsb
#
# ModuleNotFoundError: No module named 'torchvision'

# %% [markdown]
# # Bases de datos numericas - clasificacion

# %%
import pandas as pd
import numpy as np
filename = 'data/pima-indians-diabetes.data.csv'
names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class'] 
df_cla = pd.read_csv(filename, names=names) # Base de datos tipo data frame

# %% [markdown]
# # Especificación de la red

# %%
# Red 1

# %%
Red_Bay = RedNeuBay(alpha=0.001, epoch=20, criteria='cross_entropy', optimizer='SGD',
                 image_size=None, verbose=True, decay=0.0, momentum=0.9, image=False, FA_ext = None,Bay=False, save_mod ='ModiR',
                   pred_hot=True, test_size=0.2,batch_size=64,cv=True, Kfold=5)

Red_Bay.add(Tanh_Layer(8,13))    #Capa de entrada
Red_Bay.add(Tanh_Layer(13,8))   #Capa oculta
#Red_Bay.add(SoftmaxBay_Layer(10,2))     #Capa final bayesiana
Red_Bay.add(Softmax_Layer(8,2))
#Red_Bay.add(Sigmoid_Layer(8,1))  # Capa final 
# Si deseara aplicar una funcion exttra ala salida de las capas por ejemplo una softmax - colocar en funcion  
print(Red_Bay)
#out = Red_Bay.train(df_cla=df_cla) #Sin cross validacion 
out = Red_Bay.cv_train(df_cla=df_cla) #Con cross validacion 
out
# Out:
# ******************RedNeuBay summary******************
#     Layers         3
#     Criteria     cross_entropy
#     Optimizer     SGD
#     Epoch          20
# Learning rate  0.001000
#     Decay      0.000000
#     Momentum      0.90
#
# ---------------Train---------------
# Dimension = 615 X 9 - en cv= 1
# -----------------------------------
# -----------------------------------
#    Frecuencia por clase
# 0                   397
# 1                   218
# -----------------------------------
# ----------------------------------------
# --Iniciando de entrenamiento Kfold= 1 --
# epoch 1/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.7513
# Accuracy: 35.45%
# epoch 2/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.7382
# Accuracy: 35.45%
# epoch 3/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.7221
# Accuracy: 35.45%
# epoch 4/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.7102
# Accuracy: 38.37%
# epoch 5/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.7007
# Accuracy: 47.32%
# epoch 6/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6932
# Accuracy: 52.2%
# epoch 7/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6868
# Accuracy: 52.52%
# epoch 8/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6811
# Accuracy: 63.74%
# epoch 9/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6754
# Accuracy: 63.9%
# epoch 10/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.671
# Accuracy: 64.55%
# epoch 11/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6672
# Accuracy: 65.2%
# epoch 12/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6637
# Accuracy: 65.53%
# epoch 13/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6613
# Accuracy: 65.85%
# epoch 14/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6586
# Accuracy: 65.37%
# epoch 15/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6565
# Accuracy: 64.55%
# epoch 16/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6545
# Accuracy: 64.39%
# epoch 17/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6529
# Accuracy: 64.39%
# epoch 18/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6514
# Accuracy: 65.04%
# epoch 19/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6498
# Accuracy: 65.04%
# epoch 20/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6487
# Accuracy: 65.04%
#
# ---------------------------------------
# The process took =  0.0178 minutes
# ---------------------------------------
# ---------------------------------------
# Final model saved as: ModiR
# Final accuracy = 65.04%
# ---------------------------------------
# ---------------------------------------
# Best model saved as: best_ModiR_K1
# Best accuracy = 65.85% in epoch:12
# ---------------------------------------
# ---------------------------------------
# -------Entrenamiento terminado---------
# ---------------------------------------
# ----------------------------------------
# --Iniciando predicción Kfold= 1 --
# ----------------------------------------
# ---------------------------------------
# --Rendimiento del modelo-Kfold= 1 --
# ----------------------------------------
# Accuracy test: 67.97%
# ---------------------------------------
# ---------------------------------------
# -------matriz de confusión-------------
# ---------------------------------------
# ---------------Train---------------
# Dimension = 615 X 9 - en cv= 2
# -----------------------------------
# -----------------------------------
#    Frecuencia por clase
# 0                   405
# 1                   210
# -----------------------------------
# ----------------------------------------
# --Iniciando de entrenamiento Kfold= 2 --
# epoch 1/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6936
# Accuracy: 56.26%
# epoch 2/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6847
# Accuracy: 57.72%
# epoch 3/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6743
# Accuracy: 58.86%
# epoch 4/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6658
# Accuracy: 60.16%
# epoch 5/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6606
# Accuracy: 61.46%
# epoch 6/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6549
# Accuracy: 62.6%
# epoch 7/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6501
# Accuracy: 63.58%
# epoch 8/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.647
# Accuracy: 64.88%
# epoch 9/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.643
# Accuracy: 65.53%
# epoch 10/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6419
# Accuracy: 65.53%
# epoch 11/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6392
# Accuracy: 66.02%
# epoch 12/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6375
# Accuracy: 66.18%
# epoch 13/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6372
# Accuracy: 66.18%
# epoch 14/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6366
# Accuracy: 66.02%
# epoch 15/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6347
# Accuracy: 66.18%
# epoch 16/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6324
# Accuracy: 65.85%
# epoch 17/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6315
# Accuracy: 65.85%
# epoch 18/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6313
# Accuracy: 65.85%
# epoch 19/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6308
# Accuracy: 65.85%
# epoch 20/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6311
# Accuracy: 65.85%
#
# ---------------------------------------
# The process took =  0.0172 minutes
# ---------------------------------------
# ---------------------------------------
# Final model saved as: ModiR
# Final accuracy = 65.85%
# ---------------------------------------
# ---------------------------------------
# Best model saved as: best_ModiR_K2
# Best accuracy = 66.18% in epoch:14
# ---------------------------------------
# ---------------------------------------
# -------Entrenamiento terminado---------
# ---------------------------------------
# ----------------------------------------
# --Iniciando predicción Kfold= 2 --
# ----------------------------------------
# ---------------------------------------
# --Rendimiento del modelo-Kfold= 2 --
# ----------------------------------------
# Accuracy test: 62.09%
# ---------------------------------------
# ---------------------------------------
# -------matriz de confusión-------------
# ---------------------------------------
# ---------------Train---------------
# Dimension = 615 X 9 - en cv= 3
# -----------------------------------
# -----------------------------------
#    Frecuencia por clase
# 0                   402
# 1                   213
# -----------------------------------
# ----------------------------------------
# --Iniciando de entrenamiento Kfold= 3 --
# epoch 1/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6506
# Accuracy: 60.0%
# epoch 2/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6416
# Accuracy: 61.79%
# epoch 3/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6308
# Accuracy: 65.2%
# epoch 4/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6273
# Accuracy: 65.85%
# epoch 5/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6251
# Accuracy: 66.34%
# epoch 6/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6231
# Accuracy: 66.67%
# epoch 7/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6216
# Accuracy: 66.83%
# epoch 8/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6202
# Accuracy: 66.99%
# epoch 9/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6197
# Accuracy: 66.83%
# epoch 10/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6192
# Accuracy: 66.67%
# epoch 11/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.619
# Accuracy: 66.18%
# epoch 12/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6181
# Accuracy: 66.83%
# epoch 13/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6171
# Accuracy: 66.83%
# epoch 14/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6177
# Accuracy: 66.02%
# epoch 15/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6167
# Accuracy: 66.5%
# epoch 16/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6164
# Accuracy: 66.83%
# epoch 17/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6166
# Accuracy: 66.83%
# epoch 18/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6159
# Accuracy: 66.5%
# epoch 19/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6152
# Accuracy: 66.5%
# epoch 20/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6155
# Accuracy: 66.83%
#
# ---------------------------------------
# The process took =  0.021 minutes
# ---------------------------------------
# ---------------------------------------
# Final model saved as: ModiR
# Final accuracy = 66.83%
# ---------------------------------------
# ---------------------------------------
# Best model saved as: best_ModiR_K3
# Best accuracy = 66.99% in epoch:7
# ---------------------------------------
# ---------------------------------------
# -------Entrenamiento terminado---------
# ---------------------------------------
# ----------------------------------------
# --Iniciando predicción Kfold= 3 --
# ----------------------------------------
# ---------------------------------------
# --Rendimiento del modelo-Kfold= 3 --
# ----------------------------------------
# Accuracy test: 62.75%
# ---------------------------------------
# ---------------------------------------
# -------matriz de confusión-------------
# ---------------------------------------
# ---------------Train---------------
# Dimension = 615 X 9 - en cv= 4
# -----------------------------------
# -----------------------------------
#    Frecuencia por clase
# 0                   396
# 1                   219
# -----------------------------------
# ----------------------------------------
# --Iniciando de entrenamiento Kfold= 4 --
# epoch 1/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6476
# Accuracy: 63.9%
# epoch 2/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6451
# Accuracy: 64.72%
# epoch 3/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6426
# Accuracy: 64.39%
# epoch 4/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6406
# Accuracy: 64.72%
# epoch 5/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6391
# Accuracy: 64.55%
# epoch 6/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6381
# Accuracy: 65.37%
# epoch 7/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6363
# Accuracy: 65.04%
# epoch 8/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6355
# Accuracy: 65.37%
# epoch 9/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6337
# Accuracy: 65.53%
# epoch 10/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6327
# Accuracy: 65.85%
# epoch 11/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6317
# Accuracy: 65.53%
# epoch 12/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6305
# Accuracy: 65.53%
# epoch 13/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6296
# Accuracy: 65.2%
# epoch 14/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6283
# Accuracy: 65.37%
# epoch 15/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6274
# Accuracy: 65.53%
# epoch 16/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6261
# Accuracy: 65.69%
# epoch 17/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6252
# Accuracy: 65.69%
# epoch 18/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6252
# Accuracy: 65.69%
# epoch 19/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6228
# Accuracy: 66.18%
# epoch 20/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6235
# Accuracy: 65.85%
#
# ---------------------------------------
# The process took =  0.0196 minutes
# ---------------------------------------
# ---------------------------------------
# Final model saved as: ModiR
# Final accuracy = 65.85%
# ---------------------------------------
# ---------------------------------------
# Best model saved as: best_ModiR_K4
# Best accuracy = 66.18% in epoch:18
# ---------------------------------------
# ---------------------------------------
# -------Entrenamiento terminado---------
# ---------------------------------------
# ----------------------------------------
# --Iniciando predicción Kfold= 4 --
# ----------------------------------------
# ---------------------------------------
# --Rendimiento del modelo-Kfold= 4 --
# ----------------------------------------
# Accuracy test: 67.32%
# ---------------------------------------
# ---------------------------------------
# -------matriz de confusión-------------
# ---------------------------------------
# ---------------Train---------------
# Dimension = 613 X 9 - en cv= 5
# -----------------------------------
# -----------------------------------
#    Frecuencia por clase
# 0                   401
# 1                   212
# -----------------------------------
# ----------------------------------------
# --Iniciando de entrenamiento Kfold= 5 --
# epoch 1/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.651
# Accuracy: 63.95%
# epoch 2/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.648
# Accuracy: 63.78%
# epoch 3/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6441
# Accuracy: 63.95%
# epoch 4/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6418
# Accuracy: 64.76%
# epoch 5/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6401
# Accuracy: 64.76%
# epoch 6/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.639
# Accuracy: 64.76%
# epoch 7/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6382
# Accuracy: 64.76%
# epoch 8/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6377
# Accuracy: 64.76%
# epoch 9/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6373
# Accuracy: 64.76%
# epoch 10/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.637
# Accuracy: 65.42%
# epoch 11/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6367
# Accuracy: 65.42%
# epoch 12/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6365
# Accuracy: 65.42%
# epoch 13/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6362
# Accuracy: 65.42%
# epoch 14/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6362
# Accuracy: 65.42%
# epoch 15/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6361
# Accuracy: 65.42%
# epoch 16/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6359
# Accuracy: 65.42%
# epoch 17/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6359
# Accuracy: 65.42%
# epoch 18/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6358
# Accuracy: 65.42%
# epoch 19/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6357
# Accuracy: 65.42%
# epoch 20/20 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:0.6356
# Accuracy: 65.42%
#
# ---------------------------------------
# The process took =  0.0245 minutes
# ---------------------------------------
# ---------------------------------------
# Final model saved as: ModiR
# Final accuracy = 65.42%
# ---------------------------------------
# ---------------------------------------
# Best model saved as: best_ModiR_K5
# Best accuracy = 65.42% in epoch:19
# ---------------------------------------
# ---------------------------------------
# -------Entrenamiento terminado---------
# ---------------------------------------
# ----------------------------------------
# --Iniciando predicción Kfold= 5 --
# ----------------------------------------
# ---------------------------------------
# --Rendimiento del modelo-Kfold= 5 --
# ----------------------------------------
# Accuracy test: 63.87%
# ---------------------------------------
# ---------------------------------------
# -------matriz de confusión-------------
# ---------------------------------------
# ---------------------------------------
# -------Rendimiento final por CV--------
# ----------------------------------------
# Accuracy test: 64.8%
# ---------------------------------------
# defaultdict(None,
#             {0: <redneuronal_bay.Layers.layers.Tanh_Layer at 0x282420a7860>,
#              1: <redneuronal_bay.Layers.layers.Tanh_Layer at 0x28241f97b38>,
#              2: <redneuronal_bay.Layers.layers.Softmax_Layer at 0x28241f97eb8>})

# %% [markdown]
# # Bases de datos con imagenes

# %%
#torch.manual_seed(123) #fijamos la semilla
transforms = torchvision.transforms.Compose([torchvision.transforms.ToTensor(),torchvision.transforms.Normalize((0.1307,), (0.3081,))])

# %%
root="./data"
train_set = dset.MNIST(root=root, train=True, transform=transforms, download=False)
test_set = dset.MNIST(root=root, train=False, transform=transforms)

# %% [markdown]
# #### Arquitectura de la red

# %%
# Red 1    image_size=784 porque imagen es de 28x28

# %%
# Modelo  Tanh y Softmax
#------------------------SIN BAYESIANO VALIDACION 50 epochs-------------------------------- 
Red_Bay = RedNeuBay(alpha=0.001, epoch=50, criteria='cross_entropy', optimizer='SGD',
                 image_size=784, verbose=True, decay=0.0, momentum=0.9, image=True, FA_ext = None,Bay=False, save_mod ='Img_ori2',
                   pred_hot=True, test_size=None,batch_size=64, cv=False, Kfold=5)

Red_Bay.add(Tanh_Layer(784,1000))    #Capa de entrada
Red_Bay.add(Tanh_Layer(1000,50))   #Capa oculta
#Red_Bay.add(SoftmaxBay_Layer(50,10))     #Capa final
Red_Bay.add(Softmax_Layer(50,10))

print(Red_Bay)
out = Red_Bay.train(train_set=train_set, test_set=test_set)
out
# Out:
# ******************RedNeuBay summary******************
#     Layers         3
#     Criteria     cross_entropy
#     Optimizer     SGD
#     Epoch          50
# Learning rate  0.001000
#     Decay      0.000000
#     Momentum      0.90
#
# ---------------Train---------------
# Numero de imagenes = 60000
# Dimension de las imagenes= 28 X 28
# -----------------------------------
# -----------------------------------
# Frecuencia total por etiqueta
# Labels
# 0    5923
# 1    6742
# 2    5958
# 3    6131
# 4    5842
# 5    5421
# 6    5918
# 7    6265
# 8    5851
# 9    5949
# dtype: int64
# -----------------------------------
# -----------------------------------
# ----Iniciando de entrenamiento-----
# epoch 1/50 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:2.2989
# Accuracy: 13.76%
# epoch 2/50 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:2.2892
# Accuracy: 20.68%
# epoch 3/50 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:2.2725
# Accuracy: 36.19%
# epoch 4/50 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:2.2503
# Accuracy: 50.3%
# epoch 5/50 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:2.2244
# Accuracy: 58.37%
# epoch 6/50 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:2.1956
# Accuracy: 62.35%
# epoch 7/50 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:2.1649
# Accuracy: 64.32%
# epoch 8/50 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:2.1333
# Accuracy: 65.51%
# epoch 9/50 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:2.1015
# Accuracy: 66.11%
# epoch 10/50 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:2.0703
# Accuracy: 66.44%
# epoch 11/50 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:2.0404
# Accuracy: 66.68%
# epoch 12/50 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:2.0123
# Accuracy: 66.78%
# epoch 13/50 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:1.9864
# Accuracy: 66.86%
# epoch 14/50 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:1.9626
# Accuracy: 67.06%
# epoch 15/50 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:1.941
# Accuracy: 67.32%
# epoch 16/50 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:1.9216
# Accuracy: 67.63%
# epoch 17/50 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:1.9041
# Accuracy: 67.85%
# epoch 18/50 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:1.8885
# Accuracy: 68.15%
# epoch 19/50 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:1.8746
# Accuracy: 68.5%
# epoch 20/50 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:1.8622
# Accuracy: 68.82%
# epoch 21/50 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:1.8512
# Accuracy: 69.08%
# epoch 22/50 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:1.8413
# Accuracy: 69.43%
# epoch 23/50 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:1.8324
# Accuracy: 69.78%
# epoch 24/50 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:1.8244
# Accuracy: 70.09%
# epoch 25/50 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:1.8172
# Accuracy: 70.39%
# epoch 26/50 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:1.8107
# Accuracy: 70.67%
# epoch 27/50 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:1.8047
# Accuracy: 70.87%
# epoch 28/50 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:1.7993
# Accuracy: 71.14%
# epoch 29/50 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:1.7943
# Accuracy: 71.42%
# epoch 30/50 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:1.7896
# Accuracy: 71.65%
# epoch 31/50 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:1.7853
# Accuracy: 71.87%
# epoch 32/50 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:1.7813
# Accuracy: 72.12%
# epoch 33/50 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:1.7775
# Accuracy: 72.36%
# epoch 34/50 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:1.7739
# Accuracy: 72.55%
# epoch 35/50 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:1.7706
# Accuracy: 72.84%
# epoch 36/50 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:1.7673
# Accuracy: 73.03%
# epoch 37/50 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:1.7643
# Accuracy: 73.26%
# epoch 38/50 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:1.7614
# Accuracy: 73.47%
# epoch 39/50 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:1.7586
# Accuracy: 73.66%
# epoch 40/50 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:1.7559
# Accuracy: 73.88%
# epoch 41/50 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:1.7534
# Accuracy: 74.08%
# epoch 42/50 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:1.7509
# Accuracy: 74.25%
# epoch 43/50 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:1.7485
# Accuracy: 74.43%
# epoch 44/50 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:1.7462
# Accuracy: 74.63%
# epoch 45/50 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:1.744
# Accuracy: 74.78%
# epoch 46/50 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:1.7418
# Accuracy: 74.94%
# epoch 47/50 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:1.7397
# Accuracy: 75.1%
# epoch 48/50 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:1.7377
# Accuracy: 75.25%
# epoch 49/50 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:1.7357
# Accuracy: 75.42%
# epoch 50/50 Progress: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> 100%
# learning rate:0.001 loss:1.7338
# Accuracy: 75.55%
# ---------------------------------------
# The process took =  10.3251 minutes
# ---------------------------------------
# ---------------------------------------
# Final model saved as: Img_ori2
# Final accuracy = 75.55%
# ---------------------------------------
# ---------------------------------------
# Best model saved as: best_Img_ori2
# Best accuracy = 75.55% in epoch:49
# ---------------------------------------
# ---------------------------------------
# -------Entrenamiento terminado---------
# ---------------------------------------
# ---------------------------------------
# -------Iniciando predicción------------
# ---------------------------------------
# ---------------------------------------
# --------Rendimiento del modelo---------
# Accuracy test: 76.71%
# ---------------------------------------
# With what name do you want to save results: Prueba
# ---------------------------------------
# ----10 predicciones iniciales----------
#    True  Predicted
# 0     7          7
# 1     2          2
# 2     1          1
# 3     0          0
# 4     4          4
# 5     1          1
# 6     4          9
# 7     9          9
# 8     5          6
# 9     9          7
# ---------------------------------------
# -------matriz de confusión-------------
# ---------------------------------------
# antes
# defaultdict(None,
#             {0: <redneuronal_bay.Layers.layers.Tanh_Layer at 0x2824d558588>,
#              1: <redneuronal_bay.Layers.layers.Tanh_Layer at 0x28241dc1cc0>,
#              2: <redneuronal_bay.Layers.layers.Softmax_Layer at 0x2824c3dd898>})
